# %%
day = 16
year = 2022

# %% [markdown]
# # Part One

# %%
part = "a"

# %% [markdown]
# The sensors have led you to the origin of the distress signal: <br>yet another handheld device, just like the one the Elves gave you. <br>However, you don't see any Elves around; instead, <br>the device is surrounded by elephants! They must have gotten lost in these tunnels, and one of the elephants apparently figured out how to turn on the distress signal.
#
# The ground rumbles again, much stronger this time. What kind of cave is this, exactly? You scan the cave with your handheld device; <br>it reports mostly igneous rock, some ash, pockets of pressurized gas, magma... this isn't just a cave, it's a volcano!
#
# You need to get the elephants out of here, quickly. Your device estimates that you have 30 minutes before the volcano erupts,<br> so you don't have time to go back out the way you came in.
#
# You scan the cave for other options and discover a network of pipes and pressure-release valves. <br>You aren't sure how such a system got into a volcano, <br>but you don't have time to complain; your device produces a report (your puzzle input) of each valve's flow rate if it were opened (in pressure per minute) and the tunnels you could use to move between the valves.
#
# There's even a valve in the room you and the elephants are currently standing in labeled AA. <br>You estimate it will take you one minute to open a single valve and one minute to follow any tunnel from one valve to another. What is the most pressure you could release?
#
# All of the valves begin closed. You start at valve AA, but it must be damaged or jammed or something: <br>its flow rate is 0, so there's no point in opening it. <br> However, you could spend one minute moving to valve BB and another minute opening it; doing so would release pressure during the remaining 28 minutes at a  <br>flow rate of 13, a total eventual pressure release of 28 * 13 = 364.  <br>Then, you could spend your third minute moving to valve CC and your fourth minute opening it, providing an additional 26 minutes of eventual pressure release at a flow rate of 2, or 52 total pressure released by valve CC.
#
# Making your way through the tunnels like this, you could probably open many or all of the valves by the time 30 minutes have elapsed.  <br>However, you need to release as much pressure as possible, so you'll need to be methodical.
#
# Work out the steps to release the most pressure in 30 minutes. What is the most pressure you can release?

# %%
import sys
import numpy as np
from copy import deepcopy

# %%
sys.path.append("..")

# %%
from utilities.utils import get_puzzle, submit_answer, read_sample_data, extract_numbers

# %%
test_expected_path = ["AA", "DD", "CC", "BB", "AA", "II", "JJ", "II", "AA", "DD", "EE", "FF", "GG", "HH", "GG", "FF", "EE", "DD", "CC"]

# %%
len(test_expected_path)
# Out:
# 19

# %%
test = read_sample_data(16)

# %%
def extract_valve(string: str):
    return string.split(" ")[1]

# %%
def extract_next_valves(string: str):
    valves = string.split(" to valve")[-1][1:].split(", ")
    valves = [v.strip() for v in valves]
    return valves

# %%
time_to_open_valve = 1
time_to_move_to_valve = 1
total_time = 30

# %%
class Valve:
    def __init__(self, valve_id: str, flow_rate: int, next_valves_ids: list):
        self.valve_id = valve_id
        self.flow_rate = flow_rate
        self.next_valves_ids = next_valves_ids
        self.next_valves = []
        self.open = False
        
    def add_next_valve(self, valve):
        if valve.valve_id in self.next_valves_ids:
            self.next_valves.append(valve)
        else:
            print(f"{valve.valve_id} is not accepted for this valve! Must be of {self.next_valves_ids}")
            
    def open_valve(self):
        self.open = True

# %%
routes = {}

# %%
def play_turn(current_valve, elapsed_time, open_valve: bool, move_valve: bool, route_id: int, route: list):
    route.append(current_valve.valve_id)
    print(f"{route_id} : elapsed time = {elapsed_time}")
    if elapsed_time == total_time:
        routes[route_id] = route
        print(f"Time up!")
        return current_valve, elapsed_time, route_id
    if not open_valve and not move_valve:
        raise ValueError("Must either open valve or move on!")
    # Option One - turn the current valve if closed
    if open_valve:
        if not current_valve.open:
            print(f"{route_id} : Opening valve of {current_valve.valve_id}")
            current_valve.open_valve()
            route.append(f"{current_valve.valve_id} opened")
            elapsed_time += time_to_open_valve
            current_valve, elapsed_time, route_id = play_turn(current_valve=current_valve, 
                                                             elapsed_time=elapsed_time, 
                                                             open_valve=False, 
                                                             move_valve=True, 
                                                             route_id=route_id, 
                                                             route=route)
        else:
            move_valve = True
         
    # Option Two - move to another valve
    if move_valve:
        for i, next_valve in enumerate(current_valve.next_valves):
            if next_valve.valve_id not in route:
                if next_valve.flow_rate == 0:
                    params = [(False, True)]
                else:
                    params = [(True, False), (False, True)]
                for j, param in enumerate(params):
                    print(f"{route_id} : Moving to {next_valve.valve_id} from {current_valve.valve_id}")
                    current_valve, elapsed_time, route_id = play_turn(current_valve=next_valve, 
                                                                      elapsed_time=elapsed_time+time_to_move_to_valve, 
                                                                     open_valve=param[0], 
                                                                     move_valve=param[1], 
                                                                     route_id=route_id+i+j, 
                                                                     route=route)
                
    if elapsed_time == total_time:
        routes[route_id] = route
        print(f"Time up!")
    return current_valve, elapsed_time, route_id

# %%
test
# Out:
# ['Valve AA has flow rate=0; tunnels lead to valves DD, II, BB',
#  'Valve BB has flow rate=13; tunnels lead to valves CC, AA',
#  'Valve CC has flow rate=2; tunnels lead to valves DD, BB',
#  'Valve DD has flow rate=20; tunnels lead to valves CC, AA, EE',
#  'Valve EE has flow rate=3; tunnels lead to valves FF, DD',
#  'Valve FF has flow rate=0; tunnels lead to valves EE, GG',
#  'Valve GG has flow rate=0; tunnels lead to valves FF, HH',
#  'Valve HH has flow rate=22; tunnel leads to valve GG',
#  'Valve II has flow rate=0; tunnels lead to valves AA, JJ',
#  'Valve JJ has flow rate=21; tunnel leads to valve II']

# %%
valves = []
for row in test:
    valve_id = extract_valve(row)
    flow_rate = extract_numbers(row)
    next_valves = extract_next_valves(row)
    valve = Valve(valve_id, flow_rate, next_valves)
    valves.append(valve)

# %%
for valve in valves:
    for valve_id in valve.next_valves_ids:
        for v in valves:
            if v.valve_id == valve_id:
                valve.add_next_valve(v)

# %%
# play_turn(valves[0], 0, False, True, 0, [])

# %% [markdown]
# ## Breadth first Search using Linked List

# %%
processed = [False] * len(valves)
discovered = [False] * len(valves)

# %%
flow_rates = {}
for valve in valves:
    flow_rates[valve.valve_id] = valve.flow_rate[0]
flow_rates
# Out:
# {'AA': 0,
#  'BB': 13,
#  'CC': 2,
#  'DD': 20,
#  'EE': 3,
#  'FF': 0,
#  'GG': 0,
#  'HH': 22,
#  'II': 0,
#  'JJ': 21}

# %%
adj_list = {}
mylist = []
def add_node(node):
  if node not in mylist:
    mylist.append(node)
  else:
    print("Node ",node," already exists!")
 
def add_edge(node1, node2):
  temp = []
  if node1 in mylist and node2 in mylist:
    if node1 not in adj_list:
      temp.append(node2)
      adj_list[node1] = temp
   
    elif node1 in adj_list:
      temp.extend(adj_list[node1])
      temp.append(node2)
      adj_list[node1] = temp
       
  else:
    print("Nodes don't exist!")
 
def graph():
  for node in adj_list:
    print(node, " ---> ", [i for i in adj_list[node]])
 
#Adding nodes
for node in valves:
    add_node(node.valve_id)
    
for node in valves:
    for nn in node.next_valves_ids:
        add_edge(node.valve_id, nn)
    
    
# add_node(0)
# add_node(1)
# add_node(2)
# add_node(3)
# add_node(4)
# #Adding edges
# add_edge(0,1)
# add_edge(1,2)
# add_edge(2,3)
# add_edge(3,0)
# add_edge(3,4)
# add_edge(4,0)
 
#Printing the graph
graph()
 
#Printing the adjacency list
print(adj_list)
# Out:
# AA  --->  ['DD', 'II', 'BB']
# BB  --->  ['CC', 'AA']
# CC  --->  ['DD', 'BB']
# DD  --->  ['CC', 'AA', 'EE']
# EE  --->  ['FF', 'DD']
# FF  --->  ['EE', 'GG']
# GG  --->  ['FF', 'HH']
# HH  --->  ['GG']
# II  --->  ['AA', 'JJ']
# JJ  --->  ['II']
# {'AA': ['DD', 'II', 'BB'], 'BB': ['CC', 'AA'], 'CC': ['DD', 'BB'], 'DD': ['CC', 'AA', 'EE'], 'EE': ['FF', 'DD'], 'FF': ['EE', 'GG'], 'GG': ['FF', 'HH'], 'HH': ['GG'], 'II': ['AA', 'JJ'], 'JJ': ['II']}

# %%
[k for k,v in flow_rates.items() if v == 0]
# Out:
# ['AA', 'FF', 'GG', 'II']

# %%
def bfs(visit_complete, graph, current_node, flows):
    # remove 0 valves
    zero_valves = [k for k,v in flow_rates.items() if v == 0]
    for node in graph:
        graph[node] = [n for n in graph[node] if n not in zero_valves]
    
    queue = []
    elapsed_time = 0
    route_id = 0
    route_ids = [0]
    route = []
    # route.append(current_node)
    queue.append((current_node, elapsed_time, route_id, route))
    routes = {}
    node_states = {}
    for n in graph.keys():
        node_states[n] = dict(flow=flow_rates[n], 
                             open=False)

 
    while queue:
        # print(queue)
        s, elapsed_time, route_id, route = queue.pop(0)
        if not node_states[s]["open"] and node_states[s]["flow"] > 0:
            node_states[s]["open"] = True
            elapsed_time += 1
        if route_id in routes.keys():
            route_id = max(route_ids) + 1
        if route_id not in route_ids:
            route_ids.append(route_id)
        # print(f"{s} added to {route_id} : {route}")
        route.append(s)
        if elapsed_time >= 30:
            print(f"Route {route_id} complete!")
            routes[route_id] = route
        else:
            # print(f"Node {s} : elapsed time -> {elapsed_time} : route -> {route_id}")

            # todo option to open the valve
            neighbours = [n for n in graph[s]]
            # print(f"Neighbours of {s} -> {neighbours}")
            for i, neighbour in enumerate(neighbours):
                queue.append((neighbour, elapsed_time +1, route_id+i, deepcopy(route)))  
    return routes

# %%
routes = bfs([], adj_list, 'AA', flow_rates)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[221], line 1
# ----> 1 routes = bfs([], adj_list, 'AA', flow_rates)
#
# Cell In[220], line 23, in bfs(visit_complete, graph, current_node, flows)
#      17     node_states[n] = dict(flow=flow_rates[n],
#      18                          open=False)
#      21 while queue:
#      22     # print(queue)
# ---> 23     s, elapsed_time, route_id, route = queue.pop(0)
#      24     if not node_states[s]["open"] and node_states[s]["flow"] > 0:
#      25         node_states[s]["open"] = True
#
# KeyboardInterrupt:

# %%
len(routes[100])
# Out:
# 15

# %% [markdown]
# ## Seems that the BFS strategy is far too slow!

# %% [markdown]
# # Trying Depth First Search (DFS)

# %%
def DFS(graph, current_node, cost: int = 1):
    queue = []
    elapsed_time = 0
    route_id = 0
    route_ids = [0]
    route = []
    # route.append(current_node)
    queue.append((current_node, elapsed_time, route_id, route))
    routes = {}
    node_states = {}
    for n in graph.keys():
        node_states[n] = dict(flow=flow_rates[n], 
                             open=False)

 
    while queue:
        # print(queue)
        s, elapsed_time, route_id, route = queue.pop()
        if not node_states[s]["open"] and node_states[s]["flow"] > 0:
            node_states[s]["open"] = True
            elapsed_time += 1
        if route_id in routes.keys():
            route_id = max(route_ids) + 1
        if route_id not in route_ids:
            route_ids.append(route_id)
        # print(f"{s} added to {route_id} : {route}")
        route.append(s)
        if elapsed_time >= 30:
            if route_id % 100 == 0:
                print(f"Route {route_id} complete!")
            routes[route_id] = route
        else:
            # print(f"Node {s} : elapsed time -> {elapsed_time} : route -> {route_id}")

            # todo option to open the valve
            neighbours = [n for n in graph[s]]
            # print(f"Neighbours of {s} -> {neighbours}")
            for i, neighbour in enumerate(neighbours):
                queue.append((neighbour, elapsed_time + cost, route_id+i, deepcopy(route)))  
    return routes

# %%
adj_list
# Out:
# {'AA': ['DD', 'II', 'BB'],
#  'BB': ['CC', 'AA'],
#  'CC': ['DD', 'BB'],
#  'DD': ['CC', 'AA', 'EE'],
#  'EE': ['FF', 'DD'],
#  'FF': ['EE', 'GG'],
#  'GG': ['FF', 'HH'],
#  'HH': ['GG'],
#  'II': ['AA', 'JJ'],
#  'JJ': ['II']}

# %%
def find_paths(graph, start, path =[], path_length=0, MAX_L=15, memo={}):
    key = start + str(path)
    if key in memo:
        return memo[key]
    if path_length>MAX_L:
        return [path]
    path = path + [start]
    if not graph.__contains__(start):
        return []
    paths = []
    for node in graph[start]:
        newpaths = find_paths(graph, node, path, path_length+1, MAX_L, memo)
        for newpath in newpaths:
            paths.append(newpath)
    memo[key] = paths
    return paths

# %%
# %%time
routes = find_paths(adj_list, "AA", MAX_L=18)
# Out:
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 8.82 µs

# %%
len(routes)
# Out:
# 2092902

# %%
[r for r in routes if r[:15] == test_expected_path[:15]]
# Out:
# []

# %%
len(routes)
# Out:
# 917945

# %%
len(routes)

# %%
routes = DFS(adj_list, "AA", cost=2)
# Out:
# Route 100 complete!
# Route 200 complete!
# Route 300 complete!
# Route 400 complete!
# Route 500 complete!
# Route 600 complete!
# Route 700 complete!
# Route 800 complete!
# Route 900 complete!
# Route 1000 complete!
# Route 1100 complete!
# Route 1200 complete!
# Route 1300 complete!
# Route 1400 complete!
# Route 1500 complete!
# Route 1600 complete!
# Route 1700 complete!
# Route 1800 complete!
# Route 1900 complete!
# Route 2000 complete!
# Route 2100 complete!
# Route 2200 complete!
# Route 2300 complete!
# Route 2400 complete!
# Route 2500 complete!
# Route 2600 complete!
# Route 2700 complete!
# Route 2800 complete!
# Route 2900 complete!
# Route 3000 complete!
# Route 3100 complete!
# Route 3200 complete!
# Route 3300 complete!
# Route 3400 complete!
# Route 3500 complete!
# Route 3600 complete!
# Route 3700 complete!
# Route 3800 complete!
# Route 3900 complete!
# Route 4000 complete!
# Route 4100 complete!
# Route 4200 complete!
# Route 4300 complete!
# Route 4400 complete!
# Route 4500 complete!
# Route 4600 complete!
# Route 4700 complete!
# Route 4800 complete!
# Route 4900 complete!
# Route 5000 complete!
# Route 5100 complete!
# Route 5200 complete!
# Route 5300 complete!
# Route 5400 complete!
# Route 5500 complete!
# Route 5600 complete!
# Route 5700 complete!
# Route 5800 complete!
# Route 5900 complete!
# Route 6000 complete!
# Route 6100 complete!
# Route 6200 complete!
# Route 6300 complete!
# Route 6400 complete!
# Route 6500 complete!
# Route 6600 complete!
# Route 6700 complete!
# Route 6800 complete!
# Route 6900 complete!
# Route 7000 complete!
# Route 7100 complete!
# Route 7200 complete!
# Route 7300 complete!
# Route 7400 complete!
# Route 7500 complete!
# Route 7600 complete!
# Route 7700 complete!
# Route 7800 complete!
# Route 7900 complete!
# Route 8000 complete!
# Route 8100 complete!
# Route 8200 complete!
# Route 8300 complete!
# Route 8400 complete!
# Route 8500 complete!
# Route 8600 complete!
# Route 8700 complete!
# Route 8800 complete!
# Route 8900 complete!
# Route 9000 complete!
# Route 9100 complete!
# Route 9200 complete!
# Route 9300 complete!
# Route 9400 complete!
# Route 9500 complete!
# Route 9600 complete!
# Route 9700 complete!
# Route 9800 complete!
# Route 9900 complete!
# Route 10000 complete!
# Route 10100 complete!
# Route 10200 complete!
# Route 10300 complete!
# Route 10400 complete!
# Route 10500 complete!
# Route 10600 complete!
# Route 10700 complete!
# Route 10800 complete!
# Route 10900 complete!
# Route 11000 complete!
# Route 11100 complete!
# Route 11200 complete!
# Route 11300 complete!
# Route 11400 complete!
# Route 11500 complete!
# Route 11600 complete!
# Route 11700 complete!
# Route 11800 complete!
# Route 11900 complete!
# Route 12000 complete!
# Route 12100 complete!
# Route 12200 complete!
# Route 12300 complete!
# Route 12400 complete!
# Route 12500 complete!
# Route 12600 complete!
# Route 12700 complete!
# Route 12800 complete!
# Route 12900 complete!
# Route 13000 complete!
# Route 13100 complete!
# Route 13200 complete!
# Route 13300 complete!
# Route 13400 complete!
# Route 13500 complete!
# Route 13600 complete!
# Route 13700 complete!
# Route 13800 complete!
# Route 13900 complete!
# Route 14000 complete!
# Route 14100 complete!
# Route 14200 complete!
# Route 14300 complete!
# Route 14400 complete!
# Route 14500 complete!
# Route 14600 complete!
# Route 14700 complete!
# Route 14800 complete!
# Route 14900 complete!
# Route 15000 complete!
# Route 15100 complete!
# Route 15200 complete!
# Route 15300 complete!
# Route 15400 complete!
# Route 15500 complete!
# Route 15600 complete!
# Route 15700 complete!
# Route 15800 complete!
# Route 15900 complete!
# Route 16000 complete!
# Route 16100 complete!
# Route 16200 complete!
# Route 16300 complete!
# Route 16400 complete!
# Route 16500 complete!
# Route 16600 complete!
# Route 16700 complete!
# Route 16800 complete!
# Route 16900 complete!
# Route 17100 complete!
# Route 17200 complete!
# Route 17000 complete!
# Route 17300 complete!
# Route 17400 complete!
# Route 17500 complete!
# Route 17600 complete!
# Route 17700 complete!
# Route 17800 complete!
# Route 17900 complete!
# Route 18000 complete!
# Route 18100 complete!
# Route 18200 complete!
# Route 18300 complete!
# Route 18400 complete!
# Route 18500 complete!
# Route 18600 complete!
# Route 18700 complete!
# Route 18800 complete!
# Route 18900 complete!
# Route 19000 complete!
# Route 19100 complete!
# Route 19200 complete!
# Route 19300 complete!
# Route 19400 complete!
# Route 19500 complete!
# Route 19600 complete!
# Route 19700 complete!
# Route 19800 complete!
# Route 19900 complete!
# Route 20000 complete!
# Route 20100 complete!
# Route 20200 complete!
# Route 20300 complete!
# Route 20400 complete!
# Route 20500 complete!
# Route 20600 complete!
# Route 20700 complete!
# Route 20800 complete!
# Route 20900 complete!
# Route 21000 complete!
# Route 21100 complete!
# Route 21200 complete!
# Route 21300 complete!
# Route 21400 complete!
# Route 21500 complete!
# Route 21600 complete!
# Route 21700 complete!
# Route 21800 complete!
# Route 21900 complete!
# Route 22000 complete!
# Route 22100 complete!
# Route 22200 complete!
# Route 22300 complete!
# Route 22400 complete!
# Route 22500 complete!
# Route 22600 complete!
# Route 22700 complete!
# Route 22800 complete!
# Route 22900 complete!
# Route 23000 complete!
# Route 23100 complete!
# Route 23200 complete!
# Route 23400 complete!
# Route 23300 complete!
# Route 23500 complete!
# Route 23600 complete!
# Route 23700 complete!
# Route 23800 complete!
# Route 23900 complete!
# Route 24000 complete!
# Route 24100 complete!
# Route 24200 complete!
# Route 24300 complete!
# Route 24400 complete!
# Route 24500 complete!
# Route 24600 complete!
# Route 24700 complete!
# Route 24800 complete!
# Route 24900 complete!
# Route 25000 complete!
# Route 25100 complete!
# Route 25200 complete!
# Route 25300 complete!
# Route 25400 complete!
# Route 25500 complete!
# Route 25600 complete!
# Route 25700 complete!
# Route 25800 complete!
# Route 25900 complete!
# Route 26000 complete!
# Route 26100 complete!
# Route 26200 complete!
# Route 26300 complete!
# Route 26400 complete!
# Route 26500 complete!
# Route 26600 complete!
# Route 26700 complete!
# Route 26800 complete!
# Route 26900 complete!
# Route 27000 complete!
# Route 27100 complete!
# Route 27200 complete!
# Route 27300 complete!
# Route 27400 complete!
# Route 27500 complete!
# Route 27600 complete!
# Route 27700 complete!
# Route 27800 complete!
# Route 27900 complete!
# Route 28000 complete!
# Route 28100 complete!
# Route 28200 complete!
# Route 28300 complete!
# Route 28400 complete!
# Route 28500 complete!
# Route 28600 complete!
# Route 28700 complete!
# Route 28800 complete!
# Route 28900 complete!
# Route 29000 complete!
# Route 29100 complete!
# Route 29200 complete!
# Route 29300 complete!
# Route 29400 complete!
# Route 29500 complete!
# Route 29600 complete!
# Route 29700 complete!
# Route 29800 complete!
# Route 29900 complete!
# Route 30000 complete!
# Route 30100 complete!
# Route 30200 complete!
# Route 30300 complete!
# Route 30400 complete!
# Route 30500 complete!
# Route 30600 complete!
# Route 30700 complete!
# Route 30800 complete!
# Route 30900 complete!
# Route 31000 complete!
# Route 31100 complete!
# Route 31200 complete!
# Route 31300 complete!
# Route 31400 complete!
# Route 31500 complete!
# Route 31600 complete!
# Route 31700 complete!
# Route 31800 complete!
# Route 31900 complete!
# Route 32000 complete!
# Route 32100 complete!
# Route 32200 complete!
# Route 32300 complete!
# Route 32400 complete!
# Route 32500 complete!
# Route 32600 complete!
# Route 32700 complete!
# Route 32800 complete!
# Route 32900 complete!
# Route 33000 complete!
# Route 33100 complete!
# Route 33200 complete!
# Route 33300 complete!
# Route 33400 complete!
# Route 33500 complete!
# Route 33600 complete!
# Route 33700 complete!
# Route 33800 complete!
# Route 33900 complete!
# Route 34000 complete!
# Route 34100 complete!
# Route 34200 complete!
# Route 34300 complete!
# Route 34400 complete!
# Route 34500 complete!
# Route 34600 complete!
# Route 34700 complete!
# Route 34800 complete!
# Route 34900 complete!
# Route 35000 complete!
# Route 35100 complete!
# Route 35200 complete!
# Route 35300 complete!
# Route 35400 complete!
# Route 35500 complete!
# Route 35600 complete!
# Route 35700 complete!
# Route 35800 complete!
# Route 35900 complete!
# Route 36000 complete!
# Route 36100 complete!
# Route 36200 complete!
# Route 36300 complete!
# Route 36400 complete!
# Route 36500 complete!
# Route 36600 complete!
# Route 36700 complete!
# Route 36800 complete!
# Route 36900 complete!
# Route 37000 complete!
# Route 37100 complete!
# Route 37200 complete!
# Route 37300 complete!
# Route 37400 complete!
# Route 37500 complete!
# Route 37600 complete!
# Route 37700 complete!
# Route 37800 complete!
# Route 37900 complete!
# Route 38000 complete!
# Route 38100 complete!
# Route 38200 complete!
# Route 38300 complete!
# Route 38400 complete!
# Route 38500 complete!
# Route 38600 complete!
# Route 38700 complete!
# Route 38800 complete!
# Route 38900 complete!
# Route 39000 complete!
# Route 39100 complete!
# Route 39200 complete!
# Route 39300 complete!
# Route 39400 complete!
# Route 39500 complete!
# Route 39600 complete!
# Route 39700 complete!
# Route 39800 complete!
# Route 39900 complete!
# Route 40000 complete!
# Route 40100 complete!
# Route 40200 complete!
# Route 40300 complete!
# Route 40400 complete!
# Route 40500 complete!
# Route 40600 complete!
# Route 40700 complete!
# Route 40800 complete!
# Route 40900 complete!
# Route 41000 complete!
# Route 41100 complete!
# Route 41200 complete!
# Route 41300 complete!
# Route 41400 complete!
# Route 41500 complete!
# Route 41600 complete!
# Route 41700 complete!
# Route 41800 complete!
# Route 41900 complete!
# Route 42000 complete!
# Route 42100 complete!
# Route 42200 complete!
# Route 42300 complete!
# Route 42400 complete!
# Route 42500 complete!
# Route 42600 complete!
# Route 42700 complete!
# Route 42800 complete!
# Route 42900 complete!
# Route 43000 complete!
# Route 43100 complete!
# Route 43200 complete!
# Route 43300 complete!
# Route 43400 complete!
# Route 43500 complete!
# Route 43600 complete!
# Route 43700 complete!
# Route 43900 complete!
# Route 44000 complete!
# Route 43800 complete!
# Route 44100 complete!
# Route 44200 complete!
# Route 44300 complete!
# Route 44400 complete!
# Route 44500 complete!
# Route 44600 complete!
# Route 44700 complete!
# Route 44800 complete!
# Route 44900 complete!
# Route 45000 complete!
# Route 45100 complete!
# Route 45200 complete!
# Route 45300 complete!
# Route 45400 complete!
# Route 45500 complete!
# Route 45600 complete!
# Route 45700 complete!
# Route 45800 complete!
# Route 45900 complete!
# Route 46000 complete!
# Route 46100 complete!
# Route 46200 complete!
# Route 46300 complete!
# Route 46400 complete!
# Route 46500 complete!
# Route 46600 complete!
# Route 46700 complete!
# Route 46800 complete!
# Route 46900 complete!
# Route 47000 complete!
# Route 47100 complete!
# Route 47200 complete!
# Route 47300 complete!
# Route 47400 complete!
# Route 47500 complete!
# Route 47600 complete!
# Route 47700 complete!
# Route 47800 complete!
# Route 47900 complete!
# Route 48000 complete!
# Route 48100 complete!
# Route 48200 complete!
# Route 48300 complete!
# Route 48400 complete!
# Route 48500 complete!
# Route 48700 complete!
# Route 48600 complete!
# Route 48800 complete!
# Route 48900 complete!
# Route 49000 complete!
# Route 49100 complete!
# Route 49200 complete!
# Route 49300 complete!
# Route 49400 complete!
# Route 49500 complete!
# Route 49600 complete!
# Route 49700 complete!
# Route 49800 complete!
# Route 49900 complete!
# Route 50000 complete!
# Route 50100 complete!
# Route 50200 complete!
# Route 50300 complete!
# Route 50400 complete!
# Route 50500 complete!
# Route 50600 complete!
# Route 50700 complete!
# Route 50800 complete!
# Route 50900 complete!
# Route 51000 complete!
# Route 51100 complete!
# Route 51200 complete!
# Route 51300 complete!
# Route 51400 complete!
# Route 51500 complete!
# Route 51600 complete!
# Route 51700 complete!
# Route 51800 complete!
# Route 51900 complete!
# Route 52000 complete!
# Route 52100 complete!
# Route 52200 complete!
# Route 52300 complete!
# Route 52400 complete!
# Route 52500 complete!
# Route 52600 complete!
# Route 52700 complete!
# Route 52800 complete!
# Route 52900 complete!
# Route 53000 complete!
# Route 53100 complete!
# Route 53200 complete!
# Route 53300 complete!
# Route 53400 complete!
# Route 53500 complete!
# Route 53600 complete!
# Route 53700 complete!
# Route 53800 complete!
# Route 53900 complete!
# Route 54000 complete!
# Route 54100 complete!
# Route 54200 complete!
# Route 54300 complete!
# Route 54400 complete!
# Route 54500 complete!
# Route 54600 complete!
# Route 54700 complete!
# Route 54800 complete!
# Route 54900 complete!
# Route 55000 complete!
# Route 55100 complete!
# Route 55200 complete!
# Route 55300 complete!
# Route 55400 complete!
# Route 55500 complete!
# Route 55600 complete!
# Route 55700 complete!
# Route 55800 complete!
# Route 55900 complete!
# Route 56000 complete!
# Route 56100 complete!
# Route 56200 complete!
# Route 56300 complete!
# Route 56400 complete!
# Route 56600 complete!
# Route 56700 complete!
# Route 56800 complete!
# Route 56900 complete!
# Route 57000 complete!
# Route 57100 complete!
# Route 57200 complete!
# Route 57300 complete!
# Route 57400 complete!
# Route 57500 complete!
# Route 57600 complete!
# Route 56500 complete!
# Route 57700 complete!
# Route 57800 complete!
# Route 57900 complete!
# Route 58000 complete!
# Route 58100 complete!
# Route 58200 complete!
# Route 58300 complete!
# Route 58400 complete!
# Route 58500 complete!
# Route 58600 complete!
# Route 58700 complete!
# Route 58800 complete!
# Route 58900 complete!
# Route 59000 complete!
# Route 59100 complete!
# Route 59200 complete!
# Route 59300 complete!
# Route 59400 complete!
# Route 59500 complete!
# Route 59600 complete!
# Route 59700 complete!
# Route 59800 complete!
# Route 59900 complete!
# Route 60000 complete!
# Route 60100 complete!
# Route 60200 complete!
# Route 60300 complete!
# Route 60400 complete!
# Route 60500 complete!
# Route 60600 complete!
# Route 60700 complete!
# Route 60800 complete!
# Route 60900 complete!
# Route 61000 complete!
# Route 61100 complete!
# Route 61200 complete!
# Route 61300 complete!
# Route 61400 complete!
# Route 61500 complete!
# Route 61600 complete!
# Route 61700 complete!
# Route 61800 complete!
# Route 61900 complete!
# Route 62000 complete!
# Route 62100 complete!
# Route 62200 complete!
# Route 62300 complete!
# Route 62400 complete!
# Route 62500 complete!
# Route 62600 complete!
# Route 62700 complete!
# Route 62800 complete!
# Route 62900 complete!
# Route 63000 complete!
# Route 63100 complete!
# Route 63200 complete!
# Route 63300 complete!
# Route 63400 complete!
# Route 63500 complete!
# Route 63600 complete!
# Route 63700 complete!
# Route 63800 complete!
# Route 63900 complete!
# Route 64000 complete!
# Route 64100 complete!
# Route 64200 complete!
# Route 64300 complete!
# Route 64400 complete!
# Route 64500 complete!
# Route 64600 complete!
# Route 64700 complete!
# Route 64800 complete!
# Route 64900 complete!
# Route 65000 complete!
# Route 65100 complete!
# Route 65200 complete!
# Route 65300 complete!
# Route 65400 complete!
# Route 65500 complete!
# Route 65600 complete!
# Route 65700 complete!
# Route 65800 complete!
# Route 65900 complete!
# Route 66000 complete!
# Route 66100 complete!
# Route 66200 complete!
# Route 66300 complete!
# Route 66400 complete!
# Route 66500 complete!
# Route 66600 complete!
# Route 66700 complete!
# Route 66800 complete!
# Route 66900 complete!
# Route 67000 complete!
# Route 67100 complete!
# Route 67200 complete!
# Route 67300 complete!
# Route 67400 complete!
# Route 67500 complete!
# Route 67600 complete!
# Route 67700 complete!
# Route 67800 complete!
# Route 67900 complete!
# Route 68000 complete!
# Route 68100 complete!
# Route 68200 complete!
# Route 68300 complete!
# Route 68400 complete!
# Route 68500 complete!
# Route 68600 complete!
# Route 68700 complete!
# Route 68800 complete!
# Route 68900 complete!
# Route 69000 complete!
# Route 69100 complete!
# Route 69200 complete!
# Route 69300 complete!
# Route 69400 complete!
# Route 69500 complete!
# Route 69600 complete!
# Route 69700 complete!
# Route 69800 complete!
# Route 69900 complete!
# Route 70000 complete!
# Route 70100 complete!
# Route 70200 complete!
# Route 70300 complete!
# Route 70400 complete!
# Route 70500 complete!
# Route 70600 complete!
# Route 70700 complete!
# Route 70800 complete!
# Route 70900 complete!
# Route 71000 complete!
# Route 71100 complete!
# Route 71200 complete!
# Route 71300 complete!
# Route 71400 complete!
# Route 71500 complete!
# Route 71600 complete!
# Route 71700 complete!
# Route 71800 complete!
# Route 71900 complete!
# Route 72000 complete!
# Route 72100 complete!
# Route 72200 complete!
# Route 72300 complete!
# Route 72400 complete!
# Route 72500 complete!
# Route 72600 complete!
# Route 72700 complete!
# Route 72800 complete!
# Route 72900 complete!
# Route 73000 complete!
# Route 73100 complete!
# Route 73200 complete!
# Route 73300 complete!
# Route 73400 complete!
# Route 73500 complete!
# Route 73600 complete!
# Route 73700 complete!
# Route 73800 complete!
# Route 73900 complete!
# Route 74000 complete!
# Route 74100 complete!
# Route 74200 complete!
# Route 74300 complete!
# Route 74400 complete!
# Route 74500 complete!
# Route 74600 complete!
# Route 74700 complete!
# Route 74800 complete!
# Route 74900 complete!
# Route 75000 complete!
# Route 75100 complete!
# Route 75200 complete!
# Route 75300 complete!
# Route 75400 complete!
# Route 75500 complete!
# Route 75600 complete!
# Route 75700 complete!
# Route 75800 complete!
# Route 75900 complete!
# Route 76000 complete!
# Route 76100 complete!
# Route 76200 complete!
# Route 76300 complete!
# Route 76400 complete!
# Route 76500 complete!
# Route 76600 complete!
# Route 76700 complete!
# Route 76800 complete!
# Route 76900 complete!
# Route 77000 complete!
# Route 77100 complete!
# Route 77200 complete!
# Route 77300 complete!
# Route 77400 complete!
# Route 77500 complete!
# Route 77600 complete!
# Route 77700 complete!
# Route 77800 complete!
# Route 77900 complete!
# Route 78000 complete!
# Route 78100 complete!
# Route 78200 complete!
# Route 78300 complete!
# Route 78400 complete!
# Route 78500 complete!
# Route 78600 complete!
# Route 78700 complete!
# Route 78800 complete!
# Route 78900 complete!
# Route 79000 complete!
# Route 79100 complete!
# Route 79200 complete!
# Route 79300 complete!
# Route 79400 complete!
# Route 79500 complete!
# Route 79600 complete!
# Route 79700 complete!
# Route 79800 complete!
# Route 79900 complete!
# Route 80000 complete!
# Route 80100 complete!
# Route 80200 complete!
# Route 80300 complete!
# Route 80400 complete!
# Route 80500 complete!
# Route 80600 complete!
# Route 80700 complete!
# Route 80800 complete!
# Route 80900 complete!
# Route 81000 complete!
# Route 81100 complete!
# Route 81200 complete!
# Route 81300 complete!
# Route 81400 complete!
# Route 81500 complete!
# Route 81600 complete!
# Route 81700 complete!
# Route 81800 complete!
# Route 81900 complete!
# Route 82000 complete!
# Route 82100 complete!
# Route 82200 complete!
# Route 82300 complete!
# Route 82400 complete!
# Route 82500 complete!
# Route 82600 complete!
# Route 82700 complete!
# Route 82800 complete!
# Route 82900 complete!
# Route 83000 complete!
# Route 83100 complete!
# Route 83200 complete!
# Route 83300 complete!
# Route 83400 complete!
# Route 83500 complete!
# Route 83600 complete!
# Route 83700 complete!
# Route 83800 complete!
# Route 83900 complete!
# Route 84000 complete!
# Route 84100 complete!
# Route 84200 complete!
# Route 84300 complete!
# Route 84400 complete!
# Route 84500 complete!
# Route 84600 complete!
# Route 84700 complete!
# Route 84800 complete!
# Route 84900 complete!
# Route 85000 complete!
# Route 85100 complete!
# Route 85200 complete!
# Route 85300 complete!
# Route 85400 complete!
# Route 85500 complete!
# Route 85600 complete!
# Route 85700 complete!
# Route 85800 complete!
# Route 85900 complete!
# Route 86000 complete!
# Route 86100 complete!
# Route 86200 complete!
# Route 86300 complete!
# Route 86400 complete!
# Route 86500 complete!
# Route 86600 complete!
# Route 86700 complete!
# Route 86800 complete!
# Route 86900 complete!
# Route 87000 complete!
# Route 87100 complete!
# Route 87200 complete!
# Route 87300 complete!
# Route 87400 complete!
# Route 87500 complete!
# Route 87600 complete!
# Route 87700 complete!
# Route 87800 complete!
# Route 87900 complete!
# Route 88000 complete!
# Route 88100 complete!
# Route 88200 complete!
# Route 88300 complete!
# Route 88400 complete!
# Route 88500 complete!
# Route 88600 complete!
# Route 88700 complete!
# Route 88800 complete!
# Route 88900 complete!
# Route 89000 complete!
# Route 89100 complete!
# Route 89200 complete!
# Route 89300 complete!
# Route 89400 complete!
# Route 89500 complete!
# Route 89600 complete!
# Route 89700 complete!
# Route 89800 complete!
# Route 89900 complete!
# Route 90000 complete!
# Route 90100 complete!
# Route 90200 complete!
# Route 90400 complete!
# Route 90500 complete!
# Route 90600 complete!
# Route 90700 complete!
# Route 90300 complete!
# Route 90800 complete!
# Route 90900 complete!
# Route 91000 complete!
# Route 91100 complete!
# Route 91200 complete!
# Route 91300 complete!
# Route 91400 complete!
# Route 91500 complete!
# Route 91600 complete!
# Route 91700 complete!
# Route 91800 complete!
# Route 91900 complete!
# Route 92000 complete!
# Route 92100 complete!
# Route 92200 complete!
# Route 92300 complete!
# Route 92400 complete!
# Route 92500 complete!
# Route 92600 complete!
# Route 92700 complete!
# Route 92800 complete!
# Route 92900 complete!
# Route 93000 complete!
# Route 93100 complete!
# Route 93200 complete!
# Route 93300 complete!
# Route 93400 complete!

# %%
routes
# Out:
# {9: ['AA', 'BB', 'AA', 'BB', 'AA', 'BB', 'AA'],
#  8: ['AA', 'BB', 'AA', 'BB', 'AA', 'BB', 'CC'],
#  10: ['AA', 'BB', 'AA', 'BB', 'AA', 'II', 'JJ'],
#  7: ['AA', 'BB', 'AA', 'BB', 'AA', 'II', 'AA'],
#  11: ['AA', 'BB', 'AA', 'BB', 'AA', 'DD', 'EE'],
#  12: ['AA', 'BB', 'AA', 'BB', 'AA', 'DD', 'AA'],
#  6: ['AA', 'BB', 'AA', 'BB', 'AA', 'DD', 'CC'],
#  14: ['AA', 'BB', 'AA', 'BB', 'CC', 'BB', 'AA'],
#  13: ['AA', 'BB', 'AA', 'BB', 'CC', 'BB', 'CC'],
#  15: ['AA', 'BB', 'AA', 'BB', 'CC', 'DD', 'EE'],
#  16: ['AA', 'BB', 'AA', 'BB', 'CC', 'DD', 'AA'],
#  5: ['AA', 'BB', 'AA', 'BB', 'CC', 'DD', 'CC'],
#  18: ['AA', 'BB', 'AA', 'II', 'JJ', 'II', 'JJ'],
#  17: ['AA', 'BB', 'AA', 'II', 'JJ', 'II', 'AA'],
#  20: ['AA', 'BB', 'AA', 'II', 'AA', 'BB', 'AA'],
#  19: ['AA', 'BB', 'AA', 'II', 'AA', 'BB', 'CC'],
#  22: ['AA', 'BB', 'AA', 'II', 'AA', 'II', 'JJ'],
#  21: ['AA', 'BB', 'AA', 'II', 'AA', 'II', 'AA'],
#  23: ['AA', 'BB', 'AA', 'II', 'AA', 'DD', 'EE'],
#  24: ['AA', 'BB', 'AA', 'II', 'AA', 'DD', 'AA'],
#  4: ['AA', 'BB', 'AA', 'II', 'AA', 'DD', 'CC'],
#  28: ['AA', 'BB', 'AA', 'DD', 'EE', 'DD', 'EE'],
#  27: ['AA', 'BB', 'AA', 'DD', 'EE', 'DD', 'AA'],
#  26: ['AA', 'BB', 'AA', 'DD', 'EE', 'DD', 'CC'],
#  29: ['AA', 'BB', 'AA', 'DD', 'EE', 'FF', 'GG'],
#  25: ['AA', 'BB', 'AA', 'DD', 'EE', 'FF', 'EE'],
#  33: ['AA', 'BB', 'AA', 'DD', 'AA', 'BB', 'AA'],
#  32: ['AA', 'BB', 'AA', 'DD', 'AA', 'BB', 'CC'],
#  34: ['AA', 'BB', 'AA', 'DD', 'AA', 'II', 'JJ'],
#  31: ['AA', 'BB', 'AA', 'DD', 'AA', 'II', 'AA'],
#  35: ['AA', 'BB', 'AA', 'DD', 'AA', 'DD', 'EE'],
#  36: ['AA', 'BB', 'AA', 'DD', 'AA', 'DD', 'AA'],
#  30: ['AA', 'BB', 'AA', 'DD', 'AA', 'DD', 'CC'],
#  38: ['AA', 'BB', 'AA', 'DD', 'CC', 'BB', 'AA'],
#  37: ['AA', 'BB', 'AA', 'DD', 'CC', 'BB', 'CC'],
#  39: ['AA', 'BB', 'AA', 'DD', 'CC', 'DD', 'EE'],
#  40: ['AA', 'BB', 'AA', 'DD', 'CC', 'DD', 'AA'],
#  3: ['AA', 'BB', 'AA', 'DD', 'CC', 'DD', 'CC'],
#  45: ['AA', 'BB', 'CC', 'BB', 'AA', 'BB', 'AA'],
#  44: ['AA', 'BB', 'CC', 'BB', 'AA', 'BB', 'CC'],
#  46: ['AA', 'BB', 'CC', 'BB', 'AA', 'II', 'JJ'],
#  43: ['AA', 'BB', 'CC', 'BB', 'AA', 'II', 'AA'],
#  47: ['AA', 'BB', 'CC', 'BB', 'AA', 'DD', 'EE'],
#  48: ['AA', 'BB', 'CC', 'BB', 'AA', 'DD', 'AA'],
#  42: ['AA', 'BB', 'CC', 'BB', 'AA', 'DD', 'CC'],
#  50: ['AA', 'BB', 'CC', 'BB', 'CC', 'BB', 'AA'],
#  49: ['AA', 'BB', 'CC', 'BB', 'CC', 'BB', 'CC'],
#  51: ['AA', 'BB', 'CC', 'BB', 'CC', 'DD', 'EE'],
#  52: ['AA', 'BB', 'CC', 'BB', 'CC', 'DD', 'AA'],
#  41: ['AA', 'BB', 'CC', 'BB', 'CC', 'DD', 'CC'],
#  56: ['AA', 'BB', 'CC', 'DD', 'EE', 'DD', 'EE'],
#  55: ['AA', 'BB', 'CC', 'DD', 'EE', 'DD', 'AA'],
#  54: ['AA', 'BB', 'CC', 'DD', 'EE', 'DD', 'CC'],
#  57: ['AA', 'BB', 'CC', 'DD', 'EE', 'FF', 'GG'],
#  53: ['AA', 'BB', 'CC', 'DD', 'EE', 'FF', 'EE'],
#  61: ['AA', 'BB', 'CC', 'DD', 'AA', 'BB', 'AA'],
#  60: ['AA', 'BB', 'CC', 'DD', 'AA', 'BB', 'CC'],
#  62: ['AA', 'BB', 'CC', 'DD', 'AA', 'II', 'JJ'],
#  59: ['AA', 'BB', 'CC', 'DD', 'AA', 'II', 'AA'],
#  63: ['AA', 'BB', 'CC', 'DD', 'AA', 'DD', 'EE'],
#  64: ['AA', 'BB', 'CC', 'DD', 'AA', 'DD', 'AA'],
#  58: ['AA', 'BB', 'CC', 'DD', 'AA', 'DD', 'CC'],
#  66: ['AA', 'BB', 'CC', 'DD', 'CC', 'BB', 'AA'],
#  65: ['AA', 'BB', 'CC', 'DD', 'CC', 'BB', 'CC'],
#  67: ['AA', 'BB', 'CC', 'DD', 'CC', 'DD', 'EE'],
#  68: ['AA', 'BB', 'CC', 'DD', 'CC', 'DD', 'AA'],
#  2: ['AA', 'BB', 'CC', 'DD', 'CC', 'DD', 'CC'],
#  71: ['AA', 'II', 'JJ', 'II', 'JJ', 'II', 'JJ'],
#  70: ['AA', 'II', 'JJ', 'II', 'JJ', 'II', 'AA'],
#  73: ['AA', 'II', 'JJ', 'II', 'AA', 'BB', 'AA'],
#  72: ['AA', 'II', 'JJ', 'II', 'AA', 'BB', 'CC'],
#  75: ['AA', 'II', 'JJ', 'II', 'AA', 'II', 'JJ'],
#  74: ['AA', 'II', 'JJ', 'II', 'AA', 'II', 'AA'],
#  76: ['AA', 'II', 'JJ', 'II', 'AA', 'DD', 'EE'],
#  77: ['AA', 'II', 'JJ', 'II', 'AA', 'DD', 'AA'],
#  69: ['AA', 'II', 'JJ', 'II', 'AA', 'DD', 'CC'],
#  82: ['AA', 'II', 'AA', 'BB', 'AA', 'BB', 'AA'],
#  81: ['AA', 'II', 'AA', 'BB', 'AA', 'BB', 'CC'],
#  83: ['AA', 'II', 'AA', 'BB', 'AA', 'II', 'JJ'],
#  80: ['AA', 'II', 'AA', 'BB', 'AA', 'II', 'AA'],
#  84: ['AA', 'II', 'AA', 'BB', 'AA', 'DD', 'EE'],
#  85: ['AA', 'II', 'AA', 'BB', 'AA', 'DD', 'AA'],
#  79: ['AA', 'II', 'AA', 'BB', 'AA', 'DD', 'CC'],
#  87: ['AA', 'II', 'AA', 'BB', 'CC', 'BB', 'AA'],
#  86: ['AA', 'II', 'AA', 'BB', 'CC', 'BB', 'CC'],
#  88: ['AA', 'II', 'AA', 'BB', 'CC', 'DD', 'EE'],
#  89: ['AA', 'II', 'AA', 'BB', 'CC', 'DD', 'AA'],
#  78: ['AA', 'II', 'AA', 'BB', 'CC', 'DD', 'CC'],
#  92: ['AA', 'II', 'AA', 'II', 'JJ', 'II', 'JJ'],
#  91: ['AA', 'II', 'AA', 'II', 'JJ', 'II', 'AA'],
#  94: ['AA', 'II', 'AA', 'II', 'AA', 'BB', 'AA'],
#  93: ['AA', 'II', 'AA', 'II', 'AA', 'BB', 'CC'],
#  96: ['AA', 'II', 'AA', 'II', 'AA', 'II', 'JJ'],
#  95: ['AA', 'II', 'AA', 'II', 'AA', 'II', 'AA'],
#  97: ['AA', 'II', 'AA', 'II', 'AA', 'DD', 'EE'],
#  98: ['AA', 'II', 'AA', 'II', 'AA', 'DD', 'AA'],
#  90: ['AA', 'II', 'AA', 'II', 'AA', 'DD', 'CC'],
#  102: ['AA', 'II', 'AA', 'DD', 'EE', 'DD', 'EE'],
#  101: ['AA', 'II', 'AA', 'DD', 'EE', 'DD', 'AA'],
#  100: ['AA', 'II', 'AA', 'DD', 'EE', 'DD', 'CC'],
#  103: ['AA', 'II', 'AA', 'DD', 'EE', 'FF', 'GG'],
#  99: ['AA', 'II', 'AA', 'DD', 'EE', 'FF', 'EE'],
#  107: ['AA', 'II', 'AA', 'DD', 'AA', 'BB', 'AA'],
#  106: ['AA', 'II', 'AA', 'DD', 'AA', 'BB', 'CC'],
#  108: ['AA', 'II', 'AA', 'DD', 'AA', 'II', 'JJ'],
#  105: ['AA', 'II', 'AA', 'DD', 'AA', 'II', 'AA'],
#  109: ['AA', 'II', 'AA', 'DD', 'AA', 'DD', 'EE'],
#  110: ['AA', 'II', 'AA', 'DD', 'AA', 'DD', 'AA'],
#  104: ['AA', 'II', 'AA', 'DD', 'AA', 'DD', 'CC'],
#  112: ['AA', 'II', 'AA', 'DD', 'CC', 'BB', 'AA'],
#  111: ['AA', 'II', 'AA', 'DD', 'CC', 'BB', 'CC'],
#  113: ['AA', 'II', 'AA', 'DD', 'CC', 'DD', 'EE'],
#  114: ['AA', 'II', 'AA', 'DD', 'CC', 'DD', 'AA'],
#  1: ['AA', 'II', 'AA', 'DD', 'CC', 'DD', 'CC'],
#  121: ['AA', 'DD', 'EE', 'DD', 'EE', 'DD', 'EE'],
#  120: ['AA', 'DD', 'EE', 'DD', 'EE', 'DD', 'AA'],
#  119: ['AA', 'DD', 'EE', 'DD', 'EE', 'DD', 'CC'],
#  122: ['AA', 'DD', 'EE', 'DD', 'EE', 'FF', 'GG'],
#  118: ['AA', 'DD', 'EE', 'DD', 'EE', 'FF', 'EE'],
#  124: ['AA', 'DD', 'EE', 'DD', 'AA', 'BB', 'AA'],
#  123: ['AA', 'DD', 'EE', 'DD', 'AA', 'BB', 'CC'],
#  126: ['AA', 'DD', 'EE', 'DD', 'AA', 'II', 'JJ'],
#  125: ['AA', 'DD', 'EE', 'DD', 'AA', 'II', 'AA'],
#  127: ['AA', 'DD', 'EE', 'DD', 'AA', 'DD', 'EE'],
#  128: ['AA', 'DD', 'EE', 'DD', 'AA', 'DD', 'AA'],
#  117: ['AA', 'DD', 'EE', 'DD', 'AA', 'DD', 'CC'],
#  130: ['AA', 'DD', 'EE', 'DD', 'CC', 'BB', 'AA'],
#  129: ['AA', 'DD', 'EE', 'DD', 'CC', 'BB', 'CC'],
#  131: ['AA', 'DD', 'EE', 'DD', 'CC', 'DD', 'EE'],
#  132: ['AA', 'DD', 'EE', 'DD', 'CC', 'DD', 'AA'],
#  116: ['AA', 'DD', 'EE', 'DD', 'CC', 'DD', 'CC'],
#  134: ['AA', 'DD', 'EE', 'FF', 'GG', 'HH', 'GG'],
#  135: ['AA', 'DD', 'EE', 'FF', 'GG', 'FF', 'GG'],
#  133: ['AA', 'DD', 'EE', 'FF', 'GG', 'FF', 'EE'],
#  138: ['AA', 'DD', 'EE', 'FF', 'EE', 'DD', 'EE'],
#  137: ['AA', 'DD', 'EE', 'FF', 'EE', 'DD', 'AA'],
#  136: ['AA', 'DD', 'EE', 'FF', 'EE', 'DD', 'CC'],
#  139: ['AA', 'DD', 'EE', 'FF', 'EE', 'FF', 'GG'],
#  115: ['AA', 'DD', 'EE', 'FF', 'EE', 'FF', 'EE'],
#  146: ['AA', 'DD', 'AA', 'BB', 'AA', 'BB', 'AA'],
#  145: ['AA', 'DD', 'AA', 'BB', 'AA', 'BB', 'CC'],
#  147: ['AA', 'DD', 'AA', 'BB', 'AA', 'II', 'JJ'],
#  144: ['AA', 'DD', 'AA', 'BB', 'AA', 'II', 'AA'],
#  148: ['AA', 'DD', 'AA', 'BB', 'AA', 'DD', 'EE'],
#  149: ['AA', 'DD', 'AA', 'BB', 'AA', 'DD', 'AA'],
#  143: ['AA', 'DD', 'AA', 'BB', 'AA', 'DD', 'CC'],
#  151: ['AA', 'DD', 'AA', 'BB', 'CC', 'BB', 'AA'],
#  150: ['AA', 'DD', 'AA', 'BB', 'CC', 'BB', 'CC'],
#  152: ['AA', 'DD', 'AA', 'BB', 'CC', 'DD', 'EE'],
#  153: ['AA', 'DD', 'AA', 'BB', 'CC', 'DD', 'AA'],
#  142: ['AA', 'DD', 'AA', 'BB', 'CC', 'DD', 'CC'],
#  155: ['AA', 'DD', 'AA', 'II', 'JJ', 'II', 'JJ'],
#  154: ['AA', 'DD', 'AA', 'II', 'JJ', 'II', 'AA'],
#  157: ['AA', 'DD', 'AA', 'II', 'AA', 'BB', 'AA'],
#  156: ['AA', 'DD', 'AA', 'II', 'AA', 'BB', 'CC'],
#  159: ['AA', 'DD', 'AA', 'II', 'AA', 'II', 'JJ'],
#  158: ['AA', 'DD', 'AA', 'II', 'AA', 'II', 'AA'],
#  160: ['AA', 'DD', 'AA', 'II', 'AA', 'DD', 'EE'],
#  161: ['AA', 'DD', 'AA', 'II', 'AA', 'DD', 'AA'],
#  141: ['AA', 'DD', 'AA', 'II', 'AA', 'DD', 'CC'],
#  165: ['AA', 'DD', 'AA', 'DD', 'EE', 'DD', 'EE'],
#  164: ['AA', 'DD', 'AA', 'DD', 'EE', 'DD', 'AA'],
#  163: ['AA', 'DD', 'AA', 'DD', 'EE', 'DD', 'CC'],
#  166: ['AA', 'DD', 'AA', 'DD', 'EE', 'FF', 'GG'],
#  162: ['AA', 'DD', 'AA', 'DD', 'EE', 'FF', 'EE'],
#  170: ['AA', 'DD', 'AA', 'DD', 'AA', 'BB', 'AA'],
#  169: ['AA', 'DD', 'AA', 'DD', 'AA', 'BB', 'CC'],
#  171: ['AA', 'DD', 'AA', 'DD', 'AA', 'II', 'JJ'],
#  168: ['AA', 'DD', 'AA', 'DD', 'AA', 'II', 'AA'],
#  172: ['AA', 'DD', 'AA', 'DD', 'AA', 'DD', 'EE'],
#  173: ['AA', 'DD', 'AA', 'DD', 'AA', 'DD', 'AA'],
#  167: ['AA', 'DD', 'AA', 'DD', 'AA', 'DD', 'CC'],
#  175: ['AA', 'DD', 'AA', 'DD', 'CC', 'BB', 'AA'],
#  174: ['AA', 'DD', 'AA', 'DD', 'CC', 'BB', 'CC'],
#  176: ['AA', 'DD', 'AA', 'DD', 'CC', 'DD', 'EE'],
#  177: ['AA', 'DD', 'AA', 'DD', 'CC', 'DD', 'AA'],
#  140: ['AA', 'DD', 'AA', 'DD', 'CC', 'DD', 'CC'],
#  182: ['AA', 'DD', 'CC', 'BB', 'AA', 'BB', 'AA'],
#  181: ['AA', 'DD', 'CC', 'BB', 'AA', 'BB', 'CC'],
#  183: ['AA', 'DD', 'CC', 'BB', 'AA', 'II', 'JJ'],
#  180: ['AA', 'DD', 'CC', 'BB', 'AA', 'II', 'AA'],
#  184: ['AA', 'DD', 'CC', 'BB', 'AA', 'DD', 'EE'],
#  185: ['AA', 'DD', 'CC', 'BB', 'AA', 'DD', 'AA'],
#  179: ['AA', 'DD', 'CC', 'BB', 'AA', 'DD', 'CC'],
#  187: ['AA', 'DD', 'CC', 'BB', 'CC', 'BB', 'AA'],
#  186: ['AA', 'DD', 'CC', 'BB', 'CC', 'BB', 'CC'],
#  188: ['AA', 'DD', 'CC', 'BB', 'CC', 'DD', 'EE'],
#  189: ['AA', 'DD', 'CC', 'BB', 'CC', 'DD', 'AA'],
#  178: ['AA', 'DD', 'CC', 'BB', 'CC', 'DD', 'CC'],
#  193: ['AA', 'DD', 'CC', 'DD', 'EE', 'DD', 'EE'],
#  192: ['AA', 'DD', 'CC', 'DD', 'EE', 'DD', 'AA'],
#  191: ['AA', 'DD', 'CC', 'DD', 'EE', 'DD', 'CC'],
#  194: ['AA', 'DD', 'CC', 'DD', 'EE', 'FF', 'GG'],
#  190: ['AA', 'DD', 'CC', 'DD', 'EE', 'FF', 'EE'],
#  198: ['AA', 'DD', 'CC', 'DD', 'AA', 'BB', 'AA'],
#  197: ['AA', 'DD', 'CC', 'DD', 'AA', 'BB', 'CC'],
#  199: ['AA', 'DD', 'CC', 'DD', 'AA', 'II', 'JJ'],
#  196: ['AA', 'DD', 'CC', 'DD', 'AA', 'II', 'AA'],
#  200: ['AA', 'DD', 'CC', 'DD', 'AA', 'DD', 'EE'],
#  201: ['AA', 'DD', 'CC', 'DD', 'AA', 'DD', 'AA'],
#  195: ['AA', 'DD', 'CC', 'DD', 'AA', 'DD', 'CC'],
#  203: ['AA', 'DD', 'CC', 'DD', 'CC', 'BB', 'AA'],
#  202: ['AA', 'DD', 'CC', 'DD', 'CC', 'BB', 'CC'],
#  204: ['AA', 'DD', 'CC', 'DD', 'CC', 'DD', 'EE'],
#  205: ['AA', 'DD', 'CC', 'DD', 'CC', 'DD', 'AA'],
#  0: ['AA', 'DD', 'CC', 'DD', 'CC', 'DD', 'CC']}
